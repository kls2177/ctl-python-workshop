# %% [markdown]
# # Learning by Doing: Living Planet Index Example
#
# Let's practice what we have learned throughout the asynchronous, online modules by taking a look at a new data set.
#
# We are going to examing the Living Planet Index. *"The Living Planet Index (LPI) is a measure of the state of global biological diversity based on population trends of vertebrate species from around the world. The index value is measured relative to species' populations in 1970 (i.e. 1970 = 1 or 100%)."* ([Our World in Data](https://ourworldindata.org/biodiversity)).
#
# There are lots of nuances with this data set. If you are interested in learning more, check out this [Our World in Data blog post](https://ourworldindata.org/living-planet-index-decline).
#
# I have already [downloaded this data from the this website](https://github.com/kls2177/ccia_files/blob/master/global_living_planet_index_19702020.csv.zip?raw=True). This data consists of the LPI from 1970-2020.
#
# Next, let's import the packages we will need.

# %% [markdown]
# ## I. Read in the Data

# %%
#  import packages
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Now, let's read in the data using numpy

# %%
#  read data
LPI = np.genfromtxt('global_living_planet_index_19702020.csv',delimiter=',')#,encoding='u)

# %% [markdown]
# Open the .csv file using Excel (or other similar program). What does the data look like? How many rows and how many columns do you have? How do you think this data is organized? \
# \
# We can examine the structure of our data using `numpy`. Let's take a look using the `shape` function:

# %%
#  use the shape function to look at the structure of the data

# %% [markdown]
# ## II. Reorganize the Data

# %% [markdown]
# Our data is organized by region in one long list. The regions are in the following order: Africa, Asia & Pacific, Europe and Central Asia, Freshwater, Latin American & the Caribbean, North America, World.
#
# Let's reorganize our data by region. We can use the `numpy` function, `.reshape()`, to reorganize this data by region:

# %%
#  reorganize data from (357, 2) -> (7, 51, 2) ==> 7 regions, each with 51 years.

# %% [markdown]
# What is the shape of our data now?

# %%
#  use the shape function

# %% [markdown]
# How would you access the LPI row for the World? Use slicing to find the data you want.

# %%
#  slice LPI to get the World data

# %%
#  check that you sliced correctly by looking at the shape of the data again

# %% [markdown]
# ## III. Plot the Data

# %% [markdown]
# Let's plot this data. Plot a time series of the data for the entire World only. Use [the following asynchronous module](https://kls2177.github.io/ctl-python-workshop/chapters/intermediate/02_intermediate_python.html) as your guide.

# %%
#  plot the data

# %% [markdown]
# ## IV. Analyze the Data

# %% [markdown]
# Now, let's compute the trend for the World region. Follow the example in [Exercise III of the asynchronous modules](https://kls2177.github.io/ctl-python-workshop/chapters/intermediate/03_intermediate_exercises.html).
#
# Once you have computed the trend, add the trend line to your plot.

# %%
#  compute trend, aka the slope

# %%
#  compute linear fit to data based on the trend

# %%
#  plot the data 

#  add trend line to plot

# %% [markdown]
# How would you make a bar plot with each region along the x-axis and the y-axis showing the average LPI over the last 5 years?
#
# Take the following steps:
#
# 1. First take the average over the last 5 years. You will need to use slicing.
# 2. Plot a bar plot. Here is [an example](https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html#sphx-glr-gallery-lines-bars-and-markers-bar-colors-py) that might help.

# %%
#  extract last 5 years

# %%
#  and take the average

# %%
#  check the shape of your data. You should just have 1 value for each of the 7 regions

# %% [markdown]
# How would you make a bar plot based on this data? Explore the bar plotting function [here](https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html) and try it on your own.

# %%
#  Plot a bar plot
plt.figure(figsize=(16,8))
regions = ['Africa', 'Asia & Pacific', 'Europe & Central Asia', 'Freshwater', 'Latin America & the Caribbean', 'North America', 'World']

# add plotting function

# %% [markdown]
# ## V. Further Analysis
#
# Which region has the largest trend overall?

# %%
# make a line plot with all regions plotted together on the same axis

# %% [markdown]
# What is the change in the LPI (average over the last 5 years minus the average over the first 5 years) for each region?

# %%
# expand on the steps in section IV
